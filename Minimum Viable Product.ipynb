# %% [markdown]
# # Minimum Viable Product (MVP)
# ## Nicole McBride, 8 May 2022
# ### SparkFit Wellness Community, Inc.
#
# <b>MVP Overview</b>
# * <b>Purpose:</b> SparkFit is looking to open another location for a certified StrongFirst personal training studio and wants to know what area of NYC they should consider based off of high volume subway commuters and not in close proximity to another StrongFirst certified gym.
# * <b>Goal:</b> Seek to identify an optimal area, that is not in saturated area, for SparkFit's new personal training studio based off of subway commuter volumes.
# * <b>Datasets:</b> The MTA turnstile data will be used to identify high volume traffic commuter locations and https://www.strongfirst.com/gyms/ to assess for StrongFirst certified gyms in New York.
# * <b>Process:</b> Visually explore 1 year worth of MTA to assesses for daily commuter data at the MTA station level and zip code level.
# * <b>Preliminary visualization:</b> From Apr 2021-2022, the below are the top 10 most busiest MTA stations according to cumulative entries and exits.
# * <b>Preliminary concluclusions:</b> Next steps will be to explore if any difference in these top 10 stations compared to a 3 month time window.

# %% [markdown]
# ### Top 10 Busiest Stations

# %%
ax = plt.gca()
ax.set_ylim([100000000, 550000000])
p = sns.barplot(x = "STATION",y="total_traffic",data=ten_busiest_stations);

plt.xticks(rotation=90)
p.set_ylabel("Total Traffic in 100 millions", fontsize = 12)
# Out:
# Text(0, 0.5, 'Total Traffic in 100 millions')

# %% [markdown]
# ### StrongFirst Gyms

# %% [markdown]
# * According to https://www.strongfirst.com/gyms/, there are 4 certified StrongFirst gyms in the NY area.
# * These will be assessed for promixity by zip code to the stations' zip code.
